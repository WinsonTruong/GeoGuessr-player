# %%
from datasets import load_dataset

dataset = load_dataset("stochastic/random_streetview_images")
# Out:
# Using custom data configuration stochastic--random_streetview_images-6c869b1ec2b9d705
# ...
# Extracting data files: 100%|██████████| 2/2 [00:00<00:00, 753.02it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/winsontruong/Documents/GitHub/GeoGuessr-player/GeoGuessr/notebooks/load_from_hf.ipynb Cell 1 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/winsontruong/Documents/GitHub/GeoGuessr-player/GeoGuessr/notebooks/load_from_hf.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> from datasets import load_dataset
# ----> <a href='vscode-notebook-cell:/Users/winsontruong/Documents/GitHub/GeoGuessr-player/GeoGuessr/notebooks/load_from_hf.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> dataset = load_dataset("stochastic/random_streetview_images")
#
# ...

# %%
display(dataset['train'][0]["image"], dataset['train'][0]["gps"], dataset["train"][0]['country_iso_alpha2'])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3072x569>
# '37.7327748097246_-76.50846167650553'
# 'US'
